# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
# YOUR CODE HERE
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    # YOUR CODE HERE
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        # YOUR CODE HERE
        cities.append(city)

# Print the city count to confirm sufficient count
# YOUR CODE HERE
len(cities)
# Out:
# 620

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
# YOUR CODE HERE URL =
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

#"https://api.openweathermap.org/data/2.5/weather?" + "q=" + city + "&appid=" + weather_api_key

#"http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

#"https://api.openweathermap.org/data/2.5/weather?" + "q=" + city + "&appid=" + weather_api_key

print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d2ec8678b701eaaa35d231899810ef1b

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
#printing json to see and find out how to parse in next step
#city_url = url + "&q=" + city.replace(" ","+")

#city_weather = requests.get(city_url).json()
#city_weather

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(30)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        # city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 2 of Set 1 | troitskoye
# Processing Record 3 of Set 1 | indiana
# Processing Record 4 of Set 1 | butaritari
# Processing Record 5 of Set 1 | sao gabriel da cachoeira
# Processing Record 6 of Set 1 | hithadhoo
# Processing Record 7 of Set 1 | ekibastuz
# Processing Record 8 of Set 1 | hermanus
# Processing Record 9 of Set 1 | georgetown
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | jamestown
# Processing Record 12 of Set 1 | puerto ayora
# Processing Record 13 of Set 1 | praya
# Processing Record 14 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 15 of Set 1 | castro
# Processing Record 16 of Set 1 | port elizabeth
# Processing Record 17 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 18 of Set 1 | banda aceh
# Processing Record 19 of Set 1 | boddam
# Processing Record 20 of Set 1 | vaini
# Processing Record 21 of Set 1 | los llanos de aridane
# Processing Record 22 of Set 1 | aklavik
# Processing Record 23 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 24 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 25 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 26 of Set 1 | caucaia
# Processing Record 27 of Set 1 | albany
# Processing Record 28 of Set 1 | balabac
# Processing Record 29 of Set 1 | punta arenas
# Processing Record 30 of Set 1 | eureka
# Processing Record 31 of Set 1 | baruun-urt
# Processing Record 32 of Set 1 | busselton
# Processing Record 33 of Set 1 | embonas
# City not found. Skipping...
# Processing Record 34 of Set 1 | bethel
# Processing Record 35 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 36 of Set 1 | ormara
# Processing Record 37 of Set 1 | bredasdorp
# Processing Record 38 of Set 1 | nome
# Processing Record 39 of Set 1 | severo-kurilsk
# Processing Record 40 of Set 1 | dikson
# Processing Record 41 of Set 1 | tevaitoa
# Processing Record 42 of Set 1 | rio grande
# Processing Record 43 of Set 1 | jining
# Processing Record 44 of Set 1 | faanui
# Processing Record 45 of Set 1 | doume
# Processing Record 46 of Set 1 | barentu
# Processing Record 47 of Set 1 | faya
# Processing Record 48 of Set 1 | shepsi
# Processing Record 49 of Set 1 | iqaluit
# Processing Record 50 of Set 1 | hobart
# Processing Record 1 of Set 2 | port alfred
# Processing Record 2 of Set 2 | dicabisagan
# Processing Record 3 of Set 2 | thompson
# Processing Record 4 of Set 2 | maple creek
# Processing Record 5 of Set 2 | chuy
# Processing Record 6 of Set 2 | upernavik
# Processing Record 7 of Set 2 | bluff
# Processing Record 8 of Set 2 | bafra
# Processing Record 9 of Set 2 | guerrero negro
# Processing Record 10 of Set 2 | victoria falls
# Processing Record 11 of Set 2 | ambilobe
# Processing Record 12 of Set 2 | souillac
# Processing Record 13 of Set 2 | ushuaia
# Processing Record 14 of Set 2 | touros
# Processing Record 15 of Set 2 | halalo
# City not found. Skipping...
# Processing Record 16 of Set 2 | san bartolome
# Processing Record 17 of Set 2 | kodiak
# Processing Record 18 of Set 2 | east london
# Processing Record 19 of Set 2 | oranjemund
# Processing Record 20 of Set 2 | rawson
# Processing Record 21 of Set 2 | lompoc
# Processing Record 22 of Set 2 | barbar
# City not found. Skipping...
# Processing Record 23 of Set 2 | talnakh
# Processing Record 24 of Set 2 | yerbogachen
# Processing Record 25 of Set 2 | korla
# Processing Record 26 of Set 2 | alotau
# City not found. Skipping...
# Processing Record 27 of Set 2 | avarua
# Processing Record 28 of Set 2 | saskylakh
# Processing Record 29 of Set 2 | binabalian
# Processing Record 30 of Set 2 | brasilia
# Processing Record 31 of Set 2 | cape town
# Processing Record 32 of Set 2 | zhob
# Processing Record 33 of Set 2 | constitucion
# Processing Record 34 of Set 2 | puerto escondido
# Processing Record 35 of Set 2 | matara
# Processing Record 36 of Set 2 | necochea
# Processing Record 37 of Set 2 | provideniya
# Processing Record 38 of Set 2 | saint-augustin
# Processing Record 39 of Set 2 | chokurdakh
# Processing Record 40 of Set 2 | domoni
# Processing Record 41 of Set 2 | carnarvon
# Processing Record 42 of Set 2 | hambantota
# Processing Record 43 of Set 2 | hovd
# Processing Record 44 of Set 2 | ayan
# Processing Record 45 of Set 2 | saint-philippe
# Processing Record 46 of Set 2 | lages
# Processing Record 47 of Set 2 | yangambi
# Processing Record 48 of Set 2 | tazovskiy
# Processing Record 49 of Set 2 | mataura
# Processing Record 50 of Set 2 | buncrana
# Processing Record 1 of Set 3 | san patricio
# Processing Record 2 of Set 3 | ahipara
# Processing Record 3 of Set 3 | sahrak
# City not found. Skipping...
# Processing Record 4 of Set 3 | kapaa
# Processing Record 5 of Set 3 | lazaro cardenas
# Processing Record 6 of Set 3 | oksfjord
# Processing Record 7 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 8 of Set 3 | atuona
# Processing Record 9 of Set 3 | puerto colombia
# Processing Record 10 of Set 3 | noumea
# Processing Record 11 of Set 3 | rio gallegos
# Processing Record 12 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 13 of Set 3 | sembakung
# Processing Record 14 of Set 3 | darnah
# Processing Record 15 of Set 3 | sinnai
# Processing Record 16 of Set 3 | cozumel
# Processing Record 17 of Set 3 | sitka
# Processing Record 18 of Set 3 | fortuna
# Processing Record 19 of Set 3 | inhambane
# Processing Record 20 of Set 3 | esperance
# Processing Record 21 of Set 3 | tuktoyaktuk
# Processing Record 22 of Set 3 | gizo
# Processing Record 23 of Set 3 | ambovombe
# Processing Record 24 of Set 3 | nikolskoye
# Processing Record 25 of Set 3 | sibolga
# Processing Record 26 of Set 3 | najran
# Processing Record 27 of Set 3 | yulara
# Processing Record 28 of Set 3 | nawashahr
# Processing Record 29 of Set 3 | itarema
# Processing Record 30 of Set 3 | qaanaaq
# Processing Record 31 of Set 3 | kautokeino
# Processing Record 32 of Set 3 | barrow
# Processing Record 33 of Set 3 | semey
# Processing Record 34 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 35 of Set 3 | saint george
# Processing Record 36 of Set 3 | tupik
# Processing Record 37 of Set 3 | jales
# Processing Record 38 of Set 3 | zemio
# Processing Record 39 of Set 3 | gat
# Processing Record 40 of Set 3 | sungaipenuh
# Processing Record 41 of Set 3 | buin
# Processing Record 42 of Set 3 | maldonado
# Processing Record 43 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set 3 | altar
# Processing Record 45 of Set 3 | fevralsk
# City not found. Skipping...
# Processing Record 46 of Set 3 | gamboula
# Processing Record 47 of Set 3 | luwingu
# Processing Record 48 of Set 3 | yellowknife
# Processing Record 49 of Set 3 | solsvik
# City not found. Skipping...
# Processing Record 50 of Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 1 of Set 4 | havelock
# Processing Record 2 of Set 4 | kandi
# Processing Record 3 of Set 4 | serendah
# Processing Record 4 of Set 4 | mahebourg
# Processing Record 5 of Set 4 | tiksi
# Processing Record 6 of Set 4 | thunder bay
# Processing Record 7 of Set 4 | la palma
# Processing Record 8 of Set 4 | skalistyy
# City not found. Skipping...
# Processing Record 9 of Set 4 | lebu
# Processing Record 10 of Set 4 | victoria
# Processing Record 11 of Set 4 | torbay
# Processing Record 12 of Set 4 | ribeira grande
# Processing Record 13 of Set 4 | don sak
# Processing Record 14 of Set 4 | hobyo
# Processing Record 15 of Set 4 | fort saint john
# City not found. Skipping...
# Processing Record 16 of Set 4 | wahran
# City not found. Skipping...
# Processing Record 17 of Set 4 | henties bay
# Processing Record 18 of Set 4 | cockburn town
# Processing Record 19 of Set 4 | cairns
# Processing Record 20 of Set 4 | lipin bor
# Processing Record 21 of Set 4 | san quintin
# Processing Record 22 of Set 4 | bokoro
# Processing Record 23 of Set 4 | zhigansk
# Processing Record 24 of Set 4 | lagoa
# Processing Record 25 of Set 4 | homnabad
# Processing Record 26 of Set 4 | khatanga
# Processing Record 27 of Set 4 | havoysund
# Processing Record 28 of Set 4 | totness
# Processing Record 29 of Set 4 | akyab
# Processing Record 30 of Set 4 | talcahuano
# Processing Record 31 of Set 4 | vila velha
# Processing Record 32 of Set 4 | tuggurt
# City not found. Skipping...
# Processing Record 33 of Set 4 | lumphat
# Processing Record 34 of Set 4 | portland
# Processing Record 35 of Set 4 | sagaing
# Processing Record 36 of Set 4 | wajima
# Processing Record 37 of Set 4 | vieques
# Processing Record 38 of Set 4 | carberry
# Processing Record 39 of Set 4 | namatanai
# Processing Record 40 of Set 4 | mata
# Processing Record 41 of Set 4 | bonavista
# Processing Record 42 of Set 4 | caravelas
# Processing Record 43 of Set 4 | port hedland
# Processing Record 44 of Set 4 | gornoye loo
# Processing Record 45 of Set 4 | itupiranga
# Processing Record 46 of Set 4 | tasiilaq
# Processing Record 47 of Set 4 | antofagasta
# Processing Record 48 of Set 4 | roma
# Processing Record 49 of Set 4 | new norfolk
# Processing Record 50 of Set 4 | pontes e lacerda
# Processing Record 1 of Set 5 | san andres
# Processing Record 2 of Set 5 | znamenskoye
# Processing Record 3 of Set 5 | sao joao da barra
# Processing Record 4 of Set 5 | porto novo
# Processing Record 5 of Set 5 | adrar
# Processing Record 6 of Set 5 | axim
# Processing Record 7 of Set 5 | along
# Processing Record 8 of Set 5 | alice springs
# Processing Record 9 of Set 5 | basco
# Processing Record 10 of Set 5 | santa fe
# Processing Record 11 of Set 5 | hilo
# Processing Record 12 of Set 5 | praia da vitoria
# Processing Record 13 of Set 5 | evensk
# Processing Record 14 of Set 5 | hokitika
# Processing Record 15 of Set 5 | margate
# Processing Record 16 of Set 5 | arraial do cabo
# Processing Record 17 of Set 5 | beloha
# Processing Record 18 of Set 5 | salinas
# Processing Record 19 of Set 5 | saldanha
# Processing Record 20 of Set 5 | grand-lahou
# Processing Record 21 of Set 5 | ponta do sol
# Processing Record 22 of Set 5 | mar del plata
# Processing Record 23 of Set 5 | padang
# Processing Record 24 of Set 5 | anderson
# Processing Record 25 of Set 5 | atlantic city
# Processing Record 26 of Set 5 | codrington
# Processing Record 27 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 28 of Set 5 | port hardy
# Processing Record 29 of Set 5 | qianguo
# Processing Record 30 of Set 5 | marystown
# Processing Record 31 of Set 5 | oriximina
# Processing Record 32 of Set 5 | voh
# Processing Record 33 of Set 5 | salalah
# Processing Record 34 of Set 5 | quelimane
# Processing Record 35 of Set 5 | son la
# Processing Record 36 of Set 5 | sayyan
# Processing Record 37 of Set 5 | tuatapere
# Processing Record 38 of Set 5 | cherskiy
# Processing Record 39 of Set 5 | vao
# Processing Record 40 of Set 5 | monatele
# City not found. Skipping...
# Processing Record 41 of Set 5 | airai
# Processing Record 42 of Set 5 | bolshaya atnya
# City not found. Skipping...
# Processing Record 43 of Set 5 | fare
# Processing Record 44 of Set 5 | port-gentil
# Processing Record 45 of Set 5 | pacific grove
# Processing Record 46 of Set 5 | nanortalik
# Processing Record 47 of Set 5 | gushikawa
# Processing Record 48 of Set 5 | santa cruz de la palma
# Processing Record 49 of Set 5 | laguna
# Processing Record 50 of Set 5 | gornopravdinsk
# Processing Record 1 of Set 6 | kununurra
# Processing Record 2 of Set 6 | sola
# Processing Record 3 of Set 6 | samarinda
# Processing Record 4 of Set 6 | bathsheba
# Processing Record 5 of Set 6 | santa marta
# Processing Record 6 of Set 6 | quthing
# Processing Record 7 of Set 6 | phayakkhaphum phisai
# Processing Record 8 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 9 of Set 6 | kresttsy
# Processing Record 10 of Set 6 | kaitangata
# Processing Record 11 of Set 6 | bilma
# Processing Record 12 of Set 6 | rize
# Processing Record 13 of Set 6 | rockland
# Processing Record 14 of Set 6 | horasan
# Processing Record 15 of Set 6 | bengkulu
# Processing Record 16 of Set 6 | nekhayevskiy
# Processing Record 17 of Set 6 | la romana
# Processing Record 18 of Set 6 | ziro
# Processing Record 19 of Set 6 | mount gambier
# Processing Record 20 of Set 6 | coquimbo
# Processing Record 21 of Set 6 | jambi
# Processing Record 22 of Set 6 | lewistown
# Processing Record 23 of Set 6 | fairbanks
# Processing Record 24 of Set 6 | walvis bay
# Processing Record 25 of Set 6 | yuzhno-kurilsk
# Processing Record 26 of Set 6 | nyurba
# Processing Record 27 of Set 6 | port said
# Processing Record 28 of Set 6 | loding
# Processing Record 29 of Set 6 | la ronge
# Processing Record 30 of Set 6 | nikita
# Processing Record 31 of Set 6 | alenquer
# Processing Record 32 of Set 6 | potiskum
# Processing Record 33 of Set 6 | sao filipe
# Processing Record 34 of Set 6 | burica
# City not found. Skipping...
# Processing Record 35 of Set 6 | jacareacanga
# Processing Record 36 of Set 6 | tiarei
# Processing Record 37 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 38 of Set 6 | saint-francois
# Processing Record 39 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 40 of Set 6 | bamberg
# Processing Record 41 of Set 6 | brae
# Processing Record 42 of Set 6 | cabo san lucas
# Processing Record 43 of Set 6 | ondorhaan
# City not found. Skipping...
# Processing Record 44 of Set 6 | viedma
# Processing Record 45 of Set 6 | xai-xai
# Processing Record 46 of Set 6 | fuxin
# Processing Record 47 of Set 6 | verkhnevilyuysk
# Processing Record 48 of Set 6 | srednekolymsk
# Processing Record 49 of Set 6 | doha
# Processing Record 50 of Set 6 | bollnas
# Processing Record 1 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 2 of Set 7 | longyearbyen
# Processing Record 3 of Set 7 | kropotkin
# Processing Record 4 of Set 7 | zamora
# Processing Record 5 of Set 7 | alta floresta
# Processing Record 6 of Set 7 | samana
# Processing Record 7 of Set 7 | leh
# Processing Record 8 of Set 7 | narsaq
# Processing Record 9 of Set 7 | kendari
# Processing Record 10 of Set 7 | kuandian
# Processing Record 11 of Set 7 | egvekinot
# Processing Record 12 of Set 7 | half moon bay
# Processing Record 13 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 14 of Set 7 | lorengau
# Processing Record 15 of Set 7 | mount isa
# Processing Record 16 of Set 7 | fuzhou
# Processing Record 17 of Set 7 | chapada dos guimaraes
# Processing Record 18 of Set 7 | porto feliz
# Processing Record 19 of Set 7 | sorata
# Processing Record 20 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 21 of Set 7 | leua
# Processing Record 22 of Set 7 | pevek
# Processing Record 23 of Set 7 | ust-kuyga
# Processing Record 24 of Set 7 | cukai
# Processing Record 25 of Set 7 | bay roberts
# Processing Record 26 of Set 7 | shimoda
# Processing Record 27 of Set 7 | odweyne
# Processing Record 28 of Set 7 | teya
# Processing Record 29 of Set 7 | yumen
# Processing Record 30 of Set 7 | sur
# Processing Record 31 of Set 7 | yatou
# Processing Record 32 of Set 7 | vila franca do campo
# Processing Record 33 of Set 7 | hong gai
# Processing Record 34 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 35 of Set 7 | amapa
# Processing Record 36 of Set 7 | tessalit
# Processing Record 37 of Set 7 | norman wells
# Processing Record 38 of Set 7 | oum hadjer
# Processing Record 39 of Set 7 | sumbe
# Processing Record 40 of Set 7 | marale
# Processing Record 41 of Set 7 | bonthe
# Processing Record 42 of Set 7 | anadyr
# Processing Record 43 of Set 7 | mergui
# City not found. Skipping...
# Processing Record 44 of Set 7 | atar
# Processing Record 45 of Set 7 | merauke
# Processing Record 46 of Set 7 | jambusar
# Processing Record 47 of Set 7 | bolshaya chernigovka
# City not found. Skipping...
# Processing Record 48 of Set 7 | cidreira
# Processing Record 49 of Set 7 | drayton valley
# Processing Record 50 of Set 7 | abha
# Processing Record 1 of Set 8 | paramithia
# City not found. Skipping...
# Processing Record 2 of Set 8 | ballymena
# Processing Record 3 of Set 8 | todos santos
# Processing Record 4 of Set 8 | opole
# Processing Record 5 of Set 8 | bilibino
# Processing Record 6 of Set 8 | arman
# Processing Record 7 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 8 of Set 8 | santa rosalia
# Processing Record 9 of Set 8 | chicama
# Processing Record 10 of Set 8 | ternate
# Processing Record 11 of Set 8 | waingapu
# Processing Record 12 of Set 8 | mayo
# Processing Record 13 of Set 8 | husavik
# Processing Record 14 of Set 8 | kazanka
# Processing Record 15 of Set 8 | carauari
# Processing Record 16 of Set 8 | pisco
# Processing Record 17 of Set 8 | turukhansk
# Processing Record 18 of Set 8 | dalvik
# Processing Record 19 of Set 8 | carlos chagas
# Processing Record 20 of Set 8 | omsukchan
# Processing Record 21 of Set 8 | clyde river
# Processing Record 22 of Set 8 | bambous virieux
# Processing Record 23 of Set 8 | antalaha
# Processing Record 24 of Set 8 | ca mau
# Processing Record 25 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 26 of Set 8 | hunza
# City not found. Skipping...
# Processing Record 27 of Set 8 | tura
# Processing Record 28 of Set 8 | novyy urengoy
# Processing Record 29 of Set 8 | rabo de peixe
# Processing Record 30 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 31 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 32 of Set 8 | asayita
# City not found. Skipping...
# Processing Record 33 of Set 8 | talaya
# Processing Record 34 of Set 8 | miyako
# Processing Record 35 of Set 8 | parrita
# Processing Record 36 of Set 8 | formosa
# Processing Record 37 of Set 8 | maragogi
# Processing Record 38 of Set 8 | bundaberg
# Processing Record 39 of Set 8 | katsuura
# Processing Record 40 of Set 8 | the valley
# Processing Record 41 of Set 8 | svetlaya
# Processing Record 42 of Set 8 | dom pedrito
# Processing Record 43 of Set 8 | marsa matruh
# Processing Record 44 of Set 8 | mokhsogollokh
# Processing Record 45 of Set 8 | igarka
# Processing Record 46 of Set 8 | acarau
# Processing Record 47 of Set 8 | haines junction
# Processing Record 48 of Set 8 | ilinskiy
# Processing Record 49 of Set 8 | lufilufi
# Processing Record 50 of Set 8 | sosnovo-ozerskoye
# Processing Record 1 of Set 9 | felidhoo
# City not found. Skipping...
# Processing Record 2 of Set 9 | berezovyy
# Processing Record 3 of Set 9 | zhenlai
# Processing Record 4 of Set 9 | banjarmasin
# Processing Record 5 of Set 9 | sataua
# City not found. Skipping...
# Processing Record 6 of Set 9 | amazar
# Processing Record 7 of Set 9 | batticaloa
# Processing Record 8 of Set 9 | briancon
# Processing Record 9 of Set 9 | trairi
# Processing Record 10 of Set 9 | qasigiannguit
# Processing Record 11 of Set 9 | osoyoos
# Processing Record 12 of Set 9 | tapes
# Processing Record 13 of Set 9 | pochutla
# Processing Record 14 of Set 9 | nabire
# Processing Record 15 of Set 9 | nouadhibou
# Processing Record 16 of Set 9 | makakilo city
# Processing Record 17 of Set 9 | kinablangan
# Processing Record 18 of Set 9 | aguadilla
# Processing Record 19 of Set 9 | kavaratti
# Processing Record 20 of Set 9 | tuscaloosa
# Processing Record 21 of Set 9 | bandarbeyla
# Processing Record 22 of Set 9 | pandan
# Processing Record 23 of Set 9 | monte cristi
# City not found. Skipping...
# Processing Record 24 of Set 9 | vaitape
# Processing Record 25 of Set 9 | dingle
# Processing Record 26 of Set 9 | pitimbu
# Processing Record 27 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 28 of Set 9 | acoua
# Processing Record 29 of Set 9 | cabedelo
# Processing Record 30 of Set 9 | noshiro
# Processing Record 31 of Set 9 | kalanguy
# Processing Record 32 of Set 9 | itoman
# Processing Record 33 of Set 9 | seymchan
# Processing Record 34 of Set 9 | ixtapa
# Processing Record 35 of Set 9 | partenit
# Processing Record 36 of Set 9 | jutai
# Processing Record 37 of Set 9 | puerto del rosario
# Processing Record 38 of Set 9 | vardo
# Processing Record 39 of Set 9 | kismayo
# Processing Record 40 of Set 9 | kozhva
# Processing Record 41 of Set 9 | ojinaga
# Processing Record 42 of Set 9 | afmadu
# City not found. Skipping...
# Processing Record 43 of Set 9 | lensk
# Processing Record 44 of Set 9 | solomenskoye
# Processing Record 45 of Set 9 | dawson creek
# Processing Record 46 of Set 9 | hoima
# Processing Record 47 of Set 9 | katol
# Processing Record 48 of Set 9 | nishihara
# Processing Record 49 of Set 9 | vostok
# Processing Record 50 of Set 9 | sapao
# City not found. Skipping...
# Processing Record 1 of Set 10 | palana
# Processing Record 2 of Set 10 | huejuquilla el alto
# Processing Record 3 of Set 10 | sandwick
# Processing Record 4 of Set 10 | dahra
# Processing Record 5 of Set 10 | geraldton
# Processing Record 6 of Set 10 | bayangol
# Processing Record 7 of Set 10 | aldan
# Processing Record 8 of Set 10 | mackay
# Processing Record 9 of Set 10 | termoli
# Processing Record 10 of Set 10 | denpasar
# Processing Record 11 of Set 10 | khani
# Processing Record 12 of Set 10 | bang saphan
# Processing Record 13 of Set 10 | umm kaddadah
# Processing Record 14 of Set 10 | hearst
# Processing Record 15 of Set 10 | chipinge
# Processing Record 16 of Set 10 | musson
# Processing Record 17 of Set 10 | ilulissat
# Processing Record 18 of Set 10 | abonnema
# Processing Record 19 of Set 10 | anloga
# Processing Record 20 of Set 10 | ucluelet
# Processing Record 21 of Set 10 | atambua
# Processing Record 22 of Set 10 | dolores
# Processing Record 23 of Set 10 | vilcun
# Processing Record 24 of Set 10 | svetlogorsk
# Processing Record 25 of Set 10 | port lincoln
# Processing Record 26 of Set 10 | tarnogskiy gorodok
# Processing Record 27 of Set 10 | paracuru
# Processing Record 28 of Set 10 | solnechnyy
# Processing Record 29 of Set 10 | lavrentiya
# Processing Record 30 of Set 10 | wulanhaote
# City not found. Skipping...
# Processing Record 31 of Set 10 | kalayaan
# Processing Record 32 of Set 10 | charlestown
# Processing Record 33 of Set 10 | peremyshlyany
# Processing Record 34 of Set 10 | valparaiso
# Processing Record 35 of Set 10 | lysyanka
# Processing Record 36 of Set 10 | mamallapuram
# Processing Record 37 of Set 10 | asyut
# Processing Record 38 of Set 10 | piltene
# Processing Record 39 of Set 10 | slatina
# Processing Record 40 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 41 of Set 10 | pindamonhangaba
# Processing Record 42 of Set 10 | marsh harbour
# Processing Record 43 of Set 10 | bubaque
# Processing Record 44 of Set 10 | kaeo
# Processing Record 45 of Set 10 | miraflores
# Processing Record 46 of Set 10 | leo
# Processing Record 47 of Set 10 | buraydah
# Processing Record 48 of Set 10 | casino
# Processing Record 49 of Set 10 | deputatskiy
# Processing Record 50 of Set 10 | sao felix do xingu
# Processing Record 1 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 2 of Set 11 | presidente medici
# Processing Record 3 of Set 11 | alofi
# Processing Record 4 of Set 11 | kariba
# Processing Record 5 of Set 11 | stromness
# Processing Record 6 of Set 11 | katangli
# Processing Record 7 of Set 11 | visby
# Processing Record 8 of Set 11 | sulangan
# Processing Record 9 of Set 11 | klaksvik
# Processing Record 10 of Set 11 | chkalovskoye
# Processing Record 11 of Set 11 | mayor pablo lagerenza
# Processing Record 12 of Set 11 | diapaga
# Processing Record 13 of Set 11 | kudahuvadhoo
# Processing Record 14 of Set 11 | asbe teferi
# Processing Record 15 of Set 11 | takoradi
# Processing Record 16 of Set 11 | krasnoselkup
# Processing Record 17 of Set 11 | ilhabela
# Processing Record 18 of Set 11 | kasongo
# Processing Record 19 of Set 11 | zhanakorgan
# Processing Record 20 of Set 11 | wanderlandia
# City not found. Skipping...
# Processing Record 21 of Set 11 | kloulklubed
# Processing Record 22 of Set 11 | rameswaram
# Processing Record 23 of Set 11 | kimbe
# Processing Record 24 of Set 11 | kahului
# Processing Record 25 of Set 11 | azle
# Processing Record 26 of Set 11 | oga
# Processing Record 27 of Set 11 | smithers
# Processing Record 28 of Set 11 | udachnyy
# Processing Record 29 of Set 11 | moose factory
# Processing Record 30 of Set 11 | port macquarie
# Processing Record 31 of Set 11 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 32 of Set 11 | fort nelson
# Processing Record 33 of Set 11 | agadez
# Processing Record 34 of Set 11 | soyo
# Processing Record 35 of Set 11 | ingleside
# Processing Record 36 of Set 11 | craig
# Processing Record 37 of Set 11 | manzil tamim
# City not found. Skipping...
# Processing Record 38 of Set 11 | odemis
# City not found. Skipping...
# Processing Record 39 of Set 11 | kavieng
# Processing Record 40 of Set 11 | manggar
# Processing Record 41 of Set 11 | tasbuget
# City not found. Skipping...
# Processing Record 42 of Set 11 | ken caryl
# Processing Record 43 of Set 11 | kerema
# Processing Record 44 of Set 11 | barcelos
# Processing Record 45 of Set 11 | ostashkov
# Processing Record 46 of Set 11 | port shepstone
# Processing Record 47 of Set 11 | puerto baquerizo moreno
# Processing Record 48 of Set 11 | otjimbingwe
# Processing Record 49 of Set 11 | zachagansk
# City not found. Skipping...
# Processing Record 50 of Set 11 | elizabeth city
# Processing Record 1 of Set 12 | klyuchi
# Processing Record 2 of Set 12 | sangrur
# Processing Record 3 of Set 12 | north bend
# Processing Record 4 of Set 12 | vanimo
# Processing Record 5 of Set 12 | tanggu
# Processing Record 6 of Set 12 | coari
# Processing Record 7 of Set 12 | atbasar
# Processing Record 8 of Set 12 | labuhan
# Processing Record 9 of Set 12 | shingu
# Processing Record 10 of Set 12 | plettenberg bay
# Processing Record 11 of Set 12 | bafoulabe
# Processing Record 12 of Set 12 | huancabamba
# Processing Record 13 of Set 12 | kungurtug
# Processing Record 14 of Set 12 | youghal
# Processing Record 15 of Set 12 | poum
# Processing Record 16 of Set 12 | semporna
# Processing Record 17 of Set 12 | guozhen
# Processing Record 18 of Set 12 | coahuayana
# Processing Record 19 of Set 12 | neuquen
# Processing Record 20 of Set 12 | kokopo
# Processing Record 21 of Set 12 | hirara
# Processing Record 22 of Set 12 | dolbeau
# City not found. Skipping...
# Processing Record 23 of Set 12 | kupang
# Processing Record 24 of Set 12 | avera
# Processing Record 25 of Set 12 | grand gaube
# Processing Record 26 of Set 12 | cantaura
# Processing Record 27 of Set 12 | paveh
# Processing Record 28 of Set 12 | brigantine
# Processing Record 29 of Set 12 | zunyi
# Processing Record 30 of Set 12 | hay river
# Processing Record 31 of Set 12 | hohhot
# Processing Record 32 of Set 12 | melong
# Processing Record 33 of Set 12 | saint-pierre
# Processing Record 34 of Set 12 | hasaki
# Processing Record 35 of Set 12 | balykshi
# Processing Record 36 of Set 12 | leningradskiy
# Processing Record 37 of Set 12 | singkang
# Processing Record 38 of Set 12 | piney green
# Processing Record 39 of Set 12 | nizhneyansk
# City not found. Skipping...
# Processing Record 40 of Set 12 | keti bandar
# Processing Record 41 of Set 12 | ayios kirikos
# City not found. Skipping...
# Processing Record 42 of Set 12 | moyale
# Processing Record 43 of Set 12 | longonjo
# Processing Record 44 of Set 12 | floro
# Processing Record 45 of Set 12 | broken hill
# Processing Record 46 of Set 12 | mgandu
# Processing Record 47 of Set 12 | poronaysk
# Processing Record 48 of Set 12 | carballo
# Processing Record 49 of Set 12 | ciudad bolivar
# Processing Record 50 of Set 12 | lac-megantic
# Processing Record 1 of Set 13 | luderitz
# Processing Record 2 of Set 13 | yangshan
# Processing Record 3 of Set 13 | kotka
# Processing Record 4 of Set 13 | talas
# Processing Record 5 of Set 13 | suluq
# Processing Record 6 of Set 13 | emerald
# Processing Record 7 of Set 13 | yagodnoye
# Processing Record 8 of Set 13 | bouake
# Processing Record 9 of Set 13 | pringsewu
# Processing Record 10 of Set 13 | grindavik
# Processing Record 11 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 12 of Set 13 | seshcha
# Processing Record 13 of Set 13 | logansport
# Processing Record 14 of Set 13 | kirakira
# Processing Record 15 of Set 13 | marshall
# Processing Record 16 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 17 of Set 13 | tobolsk
# Processing Record 18 of Set 13 | stokmarknes
# Processing Record 19 of Set 13 | jibuti
# Processing Record 20 of Set 13 | ogulin
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 557

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
# YOUR CODE HERE
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#                        City      Lat       Lng  Max Temp  Humidity  \
# 0                Troitskoye  52.9821   84.6757      6.53        95
# 1                   Indiana  40.0003  -86.2503     37.96        84
# 2                Butaritari   3.0707  172.7902     81.81        75
# 3  Sao Gabriel Da Cachoeira  -0.1303  -67.0892     78.60        83
# 4                 Hithadhoo  -0.6000   73.0833     81.79        69
# 5                 Ekibastuz  51.6667   75.3667      7.05        73
# 6                  Hermanus -34.4187   19.2345     70.81        76
# 7                Georgetown   5.4112  100.3354     82.33        79
# 8                   Rikitea -23.1203 -134.9692     77.58        72
# 9                 Jamestown  42.0970  -79.2353     37.02        75
#
#    Cloudiness  Wind Speed Country                 Date
# 0         100        7.99      RU  2023-01-18 15:40:14
# 1         100        5.75      US  2023-01-18 15:40:15
# 2          96       15.35      KI  2023-01-18 15:32:27
# 3           0        5.75      BR  2023-01-18 15:40:15
# 4          11        9.01      MV  2023-01-18 15:31:12
# 5          33        9.95      KZ  2023-01-18 15:35:51
# 6          35       20.27      ZA  2023-01-18 15:31:27
# 7          20        5.75      MY  2023-01-18 15:28:54
# 8          70        3.11      PF  2023-01-18 15:30:57
# 9         100       12.66      US  2023-01-18 15:30:06

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Date'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
# YOUR CODE HERE
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
# YOUR CODE HERE
city_data_df = city_data_df[new_column_order]

# Display sample data
# YOUR CODE HERE
city_data_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 8
#       4 new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
#       6 # Recreate the DataFrame by using the new column order
#       7 # YOUR CODE HERE
# ----> 8 city_data_df = city_data_df[new_column_order]
#      10 # Display sample data
#      11 # YOUR CODE HERE
#      12 city_data_df
#
# File ~/opt/miniconda3/envs/PythonData/lib/python3.8/site-packages/pandas/core/frame.py:3811, in DataFrame.__getitem__(self, key)
#    3809     if is_iterator(key):
#    3810         key = list(key)
# -> 3811     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3813 # take() does not accept boolean indexers
#    3814 if getattr(indexer, "dtype", None) == bool:
#
# File ~/opt/miniconda3/envs/PythonData/lib/python3.8/site-packages/pandas/core/indexes/base.py:6113, in Index._get_indexer_strict(self, key, axis_name)
#    6110 else:
#    6111     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6113 self._raise_if_missing(keyarr, indexer, axis_name)
#    6115 keyarr = self.take(indexer)
#    6116 if isinstance(key, Index):
#    6117     # GH 42790 - Preserve name from an Index
#
# File ~/opt/miniconda3/envs/PythonData/lib/python3.8/site-packages/pandas/core/indexes/base.py:6176, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6173     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6175 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6176 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['Current Description'] not in index"

# %%
# Display the data types of each column by using the dtypes Pandas function
# YOUR CODE HERE
city_data_df.dtypes()

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
# YOUR CODE HERE
output_data_file = "WeatherPy_Database.csv"
# Export the city_data DataFrame into a CSV file
# YOUR CODE HERE
city_data_df.to_csv(output_data_file, index_label="City_ID")
