# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
# YOUR CODE HERE
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    # YOUR CODE HERE
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        # YOUR CODE HERE
        cities.append(city)

# Print the city count to confirm sufficient count
# YOUR CODE HERE
len(cities)
# Out:
# 609

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
# YOUR CODE HERE URL =
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

#"https://api.openweathermap.org/data/2.5/weather?" + "q=" + city + "&appid=" + weather_api_key

#"http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

#"https://api.openweathermap.org/data/2.5/weather?" + "q=" + city + "&appid=" + weather_api_key

print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d2ec8678b701eaaa35d231899810ef1b

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
#printing json to see and find out how to parse in next step
#city_url = url + "&q=" + city.replace(" ","+")

#city_weather = requests.get(city_url).json()
#city_weather

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(30) #made sleep shorter

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count
    record_count += 1
    
    
    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        # YOUR CODE HERE
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into the city_data list
        # YOUR CODE HERE
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description
                         })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | natal
# Processing Record 2 of Set 1 | hilo
# Processing Record 3 of Set 1 | vila
# Processing Record 4 of Set 1 | arraial do cabo
# Processing Record 5 of Set 1 | palu
# Processing Record 6 of Set 1 | hobyo
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | tuatapere
# Processing Record 9 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 10 of Set 1 | haines junction
# Processing Record 11 of Set 1 | stornoway
# Processing Record 12 of Set 1 | port-gentil
# Processing Record 13 of Set 1 | san rafael del sur
# Processing Record 14 of Set 1 | georgetown
# Processing Record 15 of Set 1 | karasjok
# Processing Record 16 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 17 of Set 1 | burica
# City not found. Skipping...
# Processing Record 18 of Set 1 | patitirion
# Processing Record 19 of Set 1 | avarua
# Processing Record 20 of Set 1 | waingapu
# Processing Record 21 of Set 1 | mataura
# Processing Record 22 of Set 1 | ushuaia
# Processing Record 23 of Set 1 | bose
# Processing Record 24 of Set 1 | berdigestyakh
# Processing Record 25 of Set 1 | nikolskoye
# Processing Record 26 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 1 | albany
# Processing Record 28 of Set 1 | sao filipe
# Processing Record 29 of Set 1 | pevek
# Processing Record 30 of Set 1 | rosetta
# Processing Record 31 of Set 1 | marathon
# Processing Record 32 of Set 1 | tual
# Processing Record 33 of Set 1 | busselton
# Processing Record 34 of Set 1 | puerto ayora
# Processing Record 35 of Set 1 | talnakh
# Processing Record 36 of Set 1 | port hardy
# Processing Record 37 of Set 1 | torbay
# Processing Record 38 of Set 1 | kevsala
# Processing Record 39 of Set 1 | beringovskiy
# Processing Record 40 of Set 1 | pasighat
# Processing Record 41 of Set 1 | punta arenas
# Processing Record 42 of Set 1 | bluff
# Processing Record 43 of Set 1 | rio grande
# Processing Record 44 of Set 1 | east london
# Processing Record 45 of Set 1 | yellowknife
# Processing Record 46 of Set 1 | oranjemund
# Processing Record 47 of Set 1 | bethel
# Processing Record 48 of Set 1 | kupang
# Processing Record 49 of Set 1 | leeton
# Processing Record 50 of Set 1 | samana
# Processing Record 1 of Set 2 | hermanus
# Processing Record 2 of Set 2 | qaanaaq
# Processing Record 3 of Set 2 | grindavik
# Processing Record 4 of Set 2 | cape town
# Processing Record 5 of Set 2 | konya
# Processing Record 6 of Set 2 | tondon
# Processing Record 7 of Set 2 | vaini
# Processing Record 8 of Set 2 | salalah
# Processing Record 9 of Set 2 | carnarvon
# Processing Record 10 of Set 2 | chateaudun
# Processing Record 11 of Set 2 | butaritari
# Processing Record 12 of Set 2 | new norfolk
# Processing Record 13 of Set 2 | dawson creek
# Processing Record 14 of Set 2 | bengkulu
# Processing Record 15 of Set 2 | saint-philippe
# Processing Record 16 of Set 2 | vidim
# Processing Record 17 of Set 2 | atuona
# Processing Record 18 of Set 2 | chelmno
# Processing Record 19 of Set 2 | kavieng
# Processing Record 20 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 21 of Set 2 | lavrentiya
# Processing Record 22 of Set 2 | saskylakh
# Processing Record 23 of Set 2 | port elizabeth
# Processing Record 24 of Set 2 | nanortalik
# Processing Record 25 of Set 2 | manado
# Processing Record 26 of Set 2 | chaoyang
# Processing Record 27 of Set 2 | sur
# Processing Record 28 of Set 2 | cockburn town
# Processing Record 29 of Set 2 | port alfred
# Processing Record 30 of Set 2 | dubbo
# Processing Record 31 of Set 2 | oksovskiy
# Processing Record 32 of Set 2 | dikson
# Processing Record 33 of Set 2 | abu kamal
# Processing Record 34 of Set 2 | solnechnyy
# Processing Record 35 of Set 2 | saint pete beach
# Processing Record 36 of Set 2 | bambous virieux
# Processing Record 37 of Set 2 | hasaki
# Processing Record 38 of Set 2 | wajima
# Processing Record 39 of Set 2 | villa carlos paz
# Processing Record 40 of Set 2 | hithadhoo
# Processing Record 41 of Set 2 | raudeberg
# Processing Record 42 of Set 2 | clyde river
# Processing Record 43 of Set 2 | mar del plata
# Processing Record 44 of Set 2 | derzhavinsk
# Processing Record 45 of Set 2 | hobart
# Processing Record 46 of Set 2 | balkhash
# Processing Record 47 of Set 2 | hovd
# Processing Record 48 of Set 2 | chuy
# Processing Record 49 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 50 of Set 2 | gua musang
# Processing Record 1 of Set 3 | ponta do sol
# Processing Record 2 of Set 3 | homer
# Processing Record 3 of Set 3 | kenai
# Processing Record 4 of Set 3 | buckeye
# Processing Record 5 of Set 3 | maniitsoq
# Processing Record 6 of Set 3 | luderitz
# Processing Record 7 of Set 3 | lagoa
# Processing Record 8 of Set 3 | njombe
# Processing Record 9 of Set 3 | ancud
# Processing Record 10 of Set 3 | shimoda
# Processing Record 11 of Set 3 | lebu
# Processing Record 12 of Set 3 | lompoc
# Processing Record 13 of Set 3 | point pedro
# Processing Record 14 of Set 3 | dzerzhinsk
# Processing Record 15 of Set 3 | khatanga
# Processing Record 16 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 3 | sorong
# Processing Record 18 of Set 3 | ubinskoye
# Processing Record 19 of Set 3 | ituni
# City not found. Skipping...
# Processing Record 20 of Set 3 | hambantota
# Processing Record 21 of Set 3 | sicuani
# Processing Record 22 of Set 3 | henties bay
# Processing Record 23 of Set 3 | barkhan
# Processing Record 24 of Set 3 | tillabery
# City not found. Skipping...
# Processing Record 25 of Set 3 | bredasdorp
# Processing Record 26 of Set 3 | paamiut
# Processing Record 27 of Set 3 | tuktoyaktuk
# Processing Record 28 of Set 3 | esperance
# Processing Record 29 of Set 3 | hohhot
# Processing Record 30 of Set 3 | taltal
# Processing Record 31 of Set 3 | nandurbar
# Processing Record 32 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 33 of Set 3 | lazaro cardenas
# Processing Record 34 of Set 3 | akdepe
# Processing Record 35 of Set 3 | vila velha
# Processing Record 36 of Set 3 | chikoy
# City not found. Skipping...
# Processing Record 37 of Set 3 | omaruru
# Processing Record 38 of Set 3 | melfort
# Processing Record 39 of Set 3 | jamestown
# Processing Record 40 of Set 3 | rubbestadneset
# Processing Record 41 of Set 3 | tiksi
# Processing Record 42 of Set 3 | hami
# Processing Record 43 of Set 3 | synya
# Processing Record 44 of Set 3 | kaitangata
# Processing Record 45 of Set 3 | aberdeen
# Processing Record 46 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 47 of Set 3 | merauke
# Processing Record 48 of Set 3 | goderich
# Processing Record 49 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 50 of Set 3 | yaan
# Processing Record 1 of Set 4 | narsaq
# Processing Record 2 of Set 4 | porto novo
# Processing Record 3 of Set 4 | maragogi
# Processing Record 4 of Set 4 | thompson
# Processing Record 5 of Set 4 | katsuura
# Processing Record 6 of Set 4 | ixtapa
# Processing Record 7 of Set 4 | akyab
# Processing Record 8 of Set 4 | touros
# Processing Record 9 of Set 4 | saiha
# Processing Record 10 of Set 4 | hay river
# Processing Record 11 of Set 4 | thai nguyen
# Processing Record 12 of Set 4 | lorengau
# Processing Record 13 of Set 4 | severo-kurilsk
# Processing Record 14 of Set 4 | meulaboh
# Processing Record 15 of Set 4 | sokoni
# Processing Record 16 of Set 4 | sistranda
# Processing Record 17 of Set 4 | vanimo
# Processing Record 18 of Set 4 | rawson
# Processing Record 19 of Set 4 | chokurdakh
# Processing Record 20 of Set 4 | hays
# Processing Record 21 of Set 4 | novobirilyussy
# Processing Record 22 of Set 4 | pangoa
# Processing Record 23 of Set 4 | honiara
# Processing Record 24 of Set 4 | north platte
# Processing Record 25 of Set 4 | castro
# Processing Record 26 of Set 4 | ponta delgada
# Processing Record 27 of Set 4 | copiapo
# Processing Record 28 of Set 4 | banswada
# Processing Record 29 of Set 4 | pucara
# Processing Record 30 of Set 4 | taoudenni
# Processing Record 31 of Set 4 | santa rosa
# Processing Record 32 of Set 4 | sao joao da barra
# Processing Record 33 of Set 4 | richards bay
# Processing Record 34 of Set 4 | tessalit
# Processing Record 35 of Set 4 | pangai
# Processing Record 36 of Set 4 | cabo san lucas
# Processing Record 37 of Set 4 | pisco
# Processing Record 38 of Set 4 | miri
# Processing Record 39 of Set 4 | kruisfontein
# Processing Record 40 of Set 4 | gigmoto
# Processing Record 41 of Set 4 | marzuq
# Processing Record 42 of Set 4 | broome
# Processing Record 43 of Set 4 | mapiripan
# Processing Record 44 of Set 4 | novo aripuana
# Processing Record 45 of Set 4 | mahebourg
# Processing Record 46 of Set 4 | coihaique
# Processing Record 47 of Set 4 | canchungo
# Processing Record 48 of Set 4 | jizan
# Processing Record 49 of Set 4 | saint-georges
# Processing Record 50 of Set 4 | catuday
# Processing Record 1 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 2 of Set 5 | rupert
# Processing Record 3 of Set 5 | palmer
# Processing Record 4 of Set 5 | nuuk
# Processing Record 5 of Set 5 | usinsk
# Processing Record 6 of Set 5 | kirakira
# Processing Record 7 of Set 5 | trairi
# Processing Record 8 of Set 5 | vila franca do campo
# Processing Record 9 of Set 5 | gadung
# Processing Record 10 of Set 5 | cap malheureux
# Processing Record 11 of Set 5 | gillette
# Processing Record 12 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 13 of Set 5 | doha
# Processing Record 14 of Set 5 | mitsamiouli
# Processing Record 15 of Set 5 | manokwari
# Processing Record 16 of Set 5 | tsiroanomandidy
# Processing Record 17 of Set 5 | riyadh
# Processing Record 18 of Set 5 | toamasina
# Processing Record 19 of Set 5 | roebourne
# Processing Record 20 of Set 5 | khazar
# Processing Record 21 of Set 5 | kavaratti
# Processing Record 22 of Set 5 | altamira
# Processing Record 23 of Set 5 | iqaluit
# Processing Record 24 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 25 of Set 5 | sergeyevka
# Processing Record 26 of Set 5 | port hedland
# Processing Record 27 of Set 5 | tomatlan
# Processing Record 28 of Set 5 | yabelo
# Processing Record 29 of Set 5 | mount isa
# Processing Record 30 of Set 5 | maromitsa
# Processing Record 31 of Set 5 | itanagar
# Processing Record 32 of Set 5 | itarema
# Processing Record 33 of Set 5 | zambezi
# Processing Record 34 of Set 5 | korem
# Processing Record 35 of Set 5 | kapaa
# Processing Record 36 of Set 5 | tasiilaq
# Processing Record 37 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 38 of Set 5 | goure
# Processing Record 39 of Set 5 | sukhumi
# Processing Record 40 of Set 5 | lebedyn
# Processing Record 41 of Set 5 | puerto suarez
# Processing Record 42 of Set 5 | faanui
# Processing Record 43 of Set 5 | kodiak
# Processing Record 44 of Set 5 | mazatlan
# Processing Record 45 of Set 5 | novokorsunskaya
# Processing Record 46 of Set 5 | eirunepe
# Processing Record 47 of Set 5 | kimbe
# Processing Record 48 of Set 5 | novoanninskiy
# Processing Record 49 of Set 5 | pangnirtung
# Processing Record 50 of Set 5 | saint anthony
# Processing Record 1 of Set 6 | sunyani
# Processing Record 2 of Set 6 | bafq
# Processing Record 3 of Set 6 | kichera
# Processing Record 4 of Set 6 | zhob
# Processing Record 5 of Set 6 | ribeira grande
# Processing Record 6 of Set 6 | walvis bay
# Processing Record 7 of Set 6 | south venice
# Processing Record 8 of Set 6 | mujiayingzi
# Processing Record 9 of Set 6 | saldanha
# Processing Record 10 of Set 6 | agirish
# Processing Record 11 of Set 6 | saint george
# Processing Record 12 of Set 6 | pafos
# Processing Record 13 of Set 6 | guerrero negro
# Processing Record 14 of Set 6 | provideniya
# Processing Record 15 of Set 6 | lephepe
# City not found. Skipping...
# Processing Record 16 of Set 6 | poum
# Processing Record 17 of Set 6 | korla
# Processing Record 18 of Set 6 | wenling
# Processing Record 19 of Set 6 | orlik
# Processing Record 20 of Set 6 | ituporanga
# Processing Record 21 of Set 6 | huntington
# Processing Record 22 of Set 6 | shibarghan
# City not found. Skipping...
# Processing Record 23 of Set 6 | vostok
# Processing Record 24 of Set 6 | zemio
# Processing Record 25 of Set 6 | galle
# Processing Record 26 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 6 | port pirie
# Processing Record 28 of Set 6 | san cristobal
# Processing Record 29 of Set 6 | lata
# Processing Record 30 of Set 6 | vao
# Processing Record 31 of Set 6 | victoria
# Processing Record 32 of Set 6 | san angelo
# Processing Record 33 of Set 6 | coos bay
# Processing Record 34 of Set 6 | apatity
# Processing Record 35 of Set 6 | crab hill
# City not found. Skipping...
# Processing Record 36 of Set 6 | ilulissat
# Processing Record 37 of Set 6 | umm lajj
# Processing Record 38 of Set 6 | ust-ilimsk
# Processing Record 39 of Set 6 | geraldton
# Processing Record 40 of Set 6 | khyriv
# Processing Record 41 of Set 6 | la ronge
# Processing Record 42 of Set 6 | margate
# Processing Record 43 of Set 6 | svetlogorsk
# Processing Record 44 of Set 6 | selma
# Processing Record 45 of Set 6 | te anau
# Processing Record 46 of Set 6 | agartala
# Processing Record 47 of Set 6 | thinadhoo
# Processing Record 48 of Set 6 | colina
# Processing Record 49 of Set 6 | chanute
# Processing Record 50 of Set 6 | cartagena
# Processing Record 1 of Set 7 | yamada
# Processing Record 2 of Set 7 | sabang
# Processing Record 3 of Set 7 | flin flon
# Processing Record 4 of Set 7 | kemijarvi
# Processing Record 5 of Set 7 | aguie
# Processing Record 6 of Set 7 | darab
# Processing Record 7 of Set 7 | kasongo
# Processing Record 8 of Set 7 | mabaruma
# Processing Record 9 of Set 7 | ureki
# Processing Record 10 of Set 7 | yulara
# Processing Record 11 of Set 7 | joniskis
# Processing Record 12 of Set 7 | mandera
# Processing Record 13 of Set 7 | tocopilla
# Processing Record 14 of Set 7 | springbok
# Processing Record 15 of Set 7 | ugoofaaru
# Processing Record 16 of Set 7 | fandriana
# Processing Record 17 of Set 7 | aswan
# Processing Record 18 of Set 7 | puerto madryn
# Processing Record 19 of Set 7 | kharan
# Processing Record 20 of Set 7 | dinguiraye
# Processing Record 21 of Set 7 | kafanchan
# Processing Record 22 of Set 7 | fairbanks
# Processing Record 23 of Set 7 | alofi
# Processing Record 24 of Set 7 | shenjiamen
# Processing Record 25 of Set 7 | constitucion
# Processing Record 26 of Set 7 | lyubytino
# Processing Record 27 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 28 of Set 7 | tateyama
# Processing Record 29 of Set 7 | bereda
# Processing Record 30 of Set 7 | churapcha
# Processing Record 31 of Set 7 | marshall
# Processing Record 32 of Set 7 | aykhal
# Processing Record 33 of Set 7 | san quintin
# Processing Record 34 of Set 7 | srednekolymsk
# Processing Record 35 of Set 7 | barrow
# Processing Record 36 of Set 7 | beyneu
# Processing Record 37 of Set 7 | epe
# Processing Record 38 of Set 7 | alvaraes
# Processing Record 39 of Set 7 | codrington
# Processing Record 40 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 41 of Set 7 | airai
# Processing Record 42 of Set 7 | man
# Processing Record 43 of Set 7 | buraydah
# Processing Record 44 of Set 7 | opuwo
# Processing Record 45 of Set 7 | labutta
# City not found. Skipping...
# Processing Record 46 of Set 7 | sinnamary
# Processing Record 47 of Set 7 | arman
# Processing Record 48 of Set 7 | dingle
# Processing Record 49 of Set 7 | karsava
# Processing Record 50 of Set 7 | zadar
# Processing Record 1 of Set 8 | shingu
# Processing Record 2 of Set 8 | bijar
# Processing Record 3 of Set 8 | itoman
# Processing Record 4 of Set 8 | leh
# Processing Record 5 of Set 8 | anadyr
# Processing Record 6 of Set 8 | urcos
# Processing Record 7 of Set 8 | half moon bay
# Processing Record 8 of Set 8 | hare bay
# Processing Record 9 of Set 8 | sept-iles
# Processing Record 10 of Set 8 | yakshur-bodya
# City not found. Skipping...
# Processing Record 11 of Set 8 | ilhabela
# Processing Record 12 of Set 8 | hajipur
# Processing Record 13 of Set 8 | fortuna
# Processing Record 14 of Set 8 | puerto escondido
# Processing Record 15 of Set 8 | antofagasta
# Processing Record 16 of Set 8 | kloulklubed
# Processing Record 17 of Set 8 | inza
# Processing Record 18 of Set 8 | namibe
# Processing Record 19 of Set 8 | russell
# Processing Record 20 of Set 8 | brae
# Processing Record 21 of Set 8 | saint-joseph
# Processing Record 22 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 23 of Set 8 | makakilo city
# Processing Record 24 of Set 8 | sataua
# City not found. Skipping...
# Processing Record 25 of Set 8 | bosaso
# Processing Record 26 of Set 8 | verkh-usugli
# Processing Record 27 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 28 of Set 8 | seydi
# Processing Record 29 of Set 8 | upernavik
# Processing Record 30 of Set 8 | hamilton
# Processing Record 31 of Set 8 | alenquer
# Processing Record 32 of Set 8 | saint simons
# Processing Record 33 of Set 8 | adelaide
# Processing Record 34 of Set 8 | sabzevar
# Processing Record 35 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 36 of Set 8 | asau
# Processing Record 37 of Set 8 | varde
# Processing Record 38 of Set 8 | praia
# Processing Record 39 of Set 8 | havoysund
# Processing Record 40 of Set 8 | witu
# Processing Record 41 of Set 8 | sens
# Processing Record 42 of Set 8 | darnah
# Processing Record 43 of Set 8 | pozo colorado
# Processing Record 44 of Set 8 | cidreira
# Processing Record 45 of Set 8 | altay
# Processing Record 46 of Set 8 | westpunt
# City not found. Skipping...
# Processing Record 47 of Set 8 | snasa
# Processing Record 48 of Set 8 | aban
# Processing Record 49 of Set 8 | chapais
# Processing Record 50 of Set 8 | shetpe
# Processing Record 1 of Set 9 | guarapari
# Processing Record 2 of Set 9 | faridpur
# Processing Record 3 of Set 9 | mehamn
# Processing Record 4 of Set 9 | oban
# Processing Record 5 of Set 9 | sisimiut
# Processing Record 6 of Set 9 | trelew
# Processing Record 7 of Set 9 | takoradi
# Processing Record 8 of Set 9 | ust-kuyga
# Processing Record 9 of Set 9 | bathsheba
# Processing Record 10 of Set 9 | neiafu
# Processing Record 11 of Set 9 | fukue
# Processing Record 12 of Set 9 | lubbenau
# Processing Record 13 of Set 9 | acarau
# Processing Record 14 of Set 9 | deputatskiy
# Processing Record 15 of Set 9 | jiroft
# City not found. Skipping...
# Processing Record 16 of Set 9 | magadan
# Processing Record 17 of Set 9 | masallatah
# Processing Record 18 of Set 9 | leningradskiy
# Processing Record 19 of Set 9 | rocha
# Processing Record 20 of Set 9 | chisec
# Processing Record 21 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 22 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 23 of Set 9 | sovetsk
# Processing Record 24 of Set 9 | plettenberg bay
# Processing Record 25 of Set 9 | mayskiy
# Processing Record 26 of Set 9 | jiddah
# City not found. Skipping...
# Processing Record 27 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 9 | zlotow
# Processing Record 29 of Set 9 | bucharest
# Processing Record 30 of Set 9 | sembe
# Processing Record 31 of Set 9 | koungou
# Processing Record 32 of Set 9 | cayenne
# Processing Record 33 of Set 9 | gambiran
# Processing Record 34 of Set 9 | dinan
# Processing Record 35 of Set 9 | indiana
# Processing Record 36 of Set 9 | lingyuan
# Processing Record 37 of Set 9 | xiangdong
# City not found. Skipping...
# Processing Record 38 of Set 9 | price
# Processing Record 39 of Set 9 | isangel
# Processing Record 40 of Set 9 | novyy urengoy
# Processing Record 41 of Set 9 | pangkalanbuun
# Processing Record 42 of Set 9 | bheramara
# Processing Record 43 of Set 9 | tra vinh
# Processing Record 44 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 45 of Set 9 | tula
# Processing Record 46 of Set 9 | balakhninskiy
# Processing Record 47 of Set 9 | paita
# Processing Record 48 of Set 9 | pundaguitan
# Processing Record 49 of Set 9 | kiratpur
# Processing Record 50 of Set 9 | sitka
# Processing Record 1 of Set 10 | payo
# Processing Record 2 of Set 10 | tautira
# Processing Record 3 of Set 10 | ostrovnoy
# Processing Record 4 of Set 10 | lubango
# Processing Record 5 of Set 10 | qasigiannguit
# Processing Record 6 of Set 10 | simpsonville
# Processing Record 7 of Set 10 | tabou
# Processing Record 8 of Set 10 | wukari
# Processing Record 9 of Set 10 | bonavista
# Processing Record 10 of Set 10 | jalu
# Processing Record 11 of Set 10 | oksfjord
# Processing Record 12 of Set 10 | kataysk
# Processing Record 13 of Set 10 | amurzet
# Processing Record 14 of Set 10 | bastrop
# Processing Record 15 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 16 of Set 10 | qingdao
# Processing Record 17 of Set 10 | moose factory
# Processing Record 18 of Set 10 | humberto de campos
# Processing Record 19 of Set 10 | chivana
# Processing Record 20 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 21 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 22 of Set 10 | mahajanga
# Processing Record 23 of Set 10 | ouadda
# Processing Record 24 of Set 10 | abapo
# Processing Record 25 of Set 10 | adre
# Processing Record 26 of Set 10 | aubenas
# Processing Record 27 of Set 10 | devin
# Processing Record 28 of Set 10 | maldonado
# Processing Record 29 of Set 10 | mount gambier
# Processing Record 30 of Set 10 | grand-lahou
# Processing Record 31 of Set 10 | noyabrsk
# Processing Record 32 of Set 10 | linxia
# Processing Record 33 of Set 10 | devonport
# Processing Record 34 of Set 10 | borogontsy
# Processing Record 35 of Set 10 | yar-sale
# Processing Record 36 of Set 10 | baoning
# Processing Record 37 of Set 10 | huazolotitlan
# City not found. Skipping...
# Processing Record 38 of Set 10 | san pedro
# Processing Record 39 of Set 10 | mogadishu
# Processing Record 40 of Set 10 | san jose
# Processing Record 41 of Set 10 | benguela
# Processing Record 42 of Set 10 | sault sainte marie
# Processing Record 43 of Set 10 | kalabo
# Processing Record 44 of Set 10 | morondava
# Processing Record 45 of Set 10 | yeniseysk
# Processing Record 46 of Set 10 | westport
# Processing Record 47 of Set 10 | tres arroyos
# Processing Record 48 of Set 10 | lagos
# Processing Record 49 of Set 10 | kysyl-syr
# Processing Record 50 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 1 of Set 11 | nouadhibou
# Processing Record 2 of Set 11 | baykalsk
# Processing Record 3 of Set 11 | coquimbo
# Processing Record 4 of Set 11 | guiglo
# Processing Record 5 of Set 11 | clinton
# Processing Record 6 of Set 11 | paris
# Processing Record 7 of Set 11 | sylvania
# Processing Record 8 of Set 11 | herat
# Processing Record 9 of Set 11 | pedernales
# Processing Record 10 of Set 11 | saint-martin-de-crau
# Processing Record 11 of Set 11 | hammerfest
# Processing Record 12 of Set 11 | kabinda
# Processing Record 13 of Set 11 | chernyshevskiy
# Processing Record 14 of Set 11 | pringsewu
# Processing Record 15 of Set 11 | tezu
# Processing Record 16 of Set 11 | mecca
# Processing Record 17 of Set 11 | cherskiy
# Processing Record 18 of Set 11 | san juan de los lagos
# Processing Record 19 of Set 11 | acajutla
# Processing Record 20 of Set 11 | dongning
# Processing Record 21 of Set 11 | karratha
# Processing Record 22 of Set 11 | kitimat
# Processing Record 23 of Set 11 | zafarabad
# Processing Record 24 of Set 11 | douglas
# Processing Record 25 of Set 11 | tevaitoa
# Processing Record 26 of Set 11 | jiangkou
# Processing Record 27 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 28 of Set 11 | norman wells
# Processing Record 29 of Set 11 | batagay
# Processing Record 30 of Set 11 | padang
# Processing Record 31 of Set 11 | laguna
# Processing Record 32 of Set 11 | san vicente
# Processing Record 33 of Set 11 | vardo
# Processing Record 34 of Set 11 | faya
# Processing Record 35 of Set 11 | lensk
# Processing Record 36 of Set 11 | martapura
# Processing Record 37 of Set 11 | jijiga
# Processing Record 38 of Set 11 | gogrial
# Processing Record 39 of Set 11 | fonte boa
# Processing Record 40 of Set 11 | ngama
# Processing Record 41 of Set 11 | strezhevoy
# Processing Record 42 of Set 11 | bilma
# Processing Record 43 of Set 11 | ndele
# Processing Record 44 of Set 11 | saint-augustin
# Processing Record 45 of Set 11 | kerki
# City not found. Skipping...
# Processing Record 46 of Set 11 | togur
# Processing Record 47 of Set 11 | sao gabriel
# Processing Record 48 of Set 11 | zolotinka
# City not found. Skipping...
# Processing Record 49 of Set 11 | kahului
# Processing Record 50 of Set 11 | kutum
# Processing Record 1 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 2 of Set 12 | chino hills
# Processing Record 3 of Set 12 | palanga
# Processing Record 4 of Set 12 | van
# Processing Record 5 of Set 12 | puerto leguizamo
# Processing Record 6 of Set 12 | komsomolskiy
# Processing Record 7 of Set 12 | cananeia
# Processing Record 8 of Set 12 | axim
# Processing Record 9 of Set 12 | rovaniemi
# Processing Record 10 of Set 12 | tiarei
# Processing Record 11 of Set 12 | barra do garcas
# Processing Record 12 of Set 12 | skalistyy
# City not found. Skipping...
# Processing Record 13 of Set 12 | twin falls
# Processing Record 14 of Set 12 | bandarbeyla
# Processing Record 15 of Set 12 | bulungu
# Processing Record 16 of Set 12 | abu samrah
# Processing Record 17 of Set 12 | the valley
# Processing Record 18 of Set 12 | azangaro
# Processing Record 19 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 20 of Set 12 | gwadar
# Processing Record 21 of Set 12 | black river
# Processing Record 22 of Set 12 | longyearbyen
# Processing Record 23 of Set 12 | ibb
# Processing Record 24 of Set 12 | hunfeld
# Processing Record 25 of Set 12 | labuan
# Processing Record 26 of Set 12 | kurtamysh
# Processing Record 27 of Set 12 | izhma
# Processing Record 28 of Set 12 | metro
# Processing Record 29 of Set 12 | tura
# Processing Record 30 of Set 12 | klaksvik
# Processing Record 31 of Set 12 | bilibino
# Processing Record 32 of Set 12 | puerto narino
# Processing Record 33 of Set 12 | antsohihy
# Processing Record 34 of Set 12 | jurmala
# Processing Record 35 of Set 12 | dudinka
# Processing Record 36 of Set 12 | barsovo
# Processing Record 37 of Set 12 | dunedin
# Processing Record 38 of Set 12 | pyshchug
# Processing Record 39 of Set 12 | praia da vitoria
# Processing Record 40 of Set 12 | pocosol
# Processing Record 41 of Set 12 | damavand
# Processing Record 42 of Set 12 | belyy yar
# Processing Record 43 of Set 12 | athabasca
# Processing Record 44 of Set 12 | makushino
# Processing Record 45 of Set 12 | le havre
# Processing Record 46 of Set 12 | santa isabel do rio negro
# Processing Record 47 of Set 12 | victor harbor
# Processing Record 48 of Set 12 | santa cecilia
# Processing Record 49 of Set 12 | barcelos
# Processing Record 50 of Set 12 | kanye
# Processing Record 1 of Set 13 | hagere hiywet
# Processing Record 2 of Set 13 | port lincoln
# Processing Record 3 of Set 13 | huambo
# Processing Record 4 of Set 13 | port-cartier
# Processing Record 5 of Set 13 | mopipi
# Processing Record 6 of Set 13 | soe
# Processing Record 7 of Set 13 | port macquarie
# Processing Record 8 of Set 13 | kemise
# Processing Record 9 of Set 13 | nemuro
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 562

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
# YOUR CODE HERE
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#                         City      Lat       Lng  Max Temp  Humidity  \
# 0                      Natal  -5.7950  -35.2094     83.05        78
# 1                       Hilo  19.7297 -155.0900     81.28        79
# 2                       Vila  42.0304   -8.1588     34.68        90
# 3            Arraial Do Cabo -22.9661  -42.0278     85.96        74
# 4                       Palu  -0.8917  119.8707     74.68        95
# 5                      Hobyo   5.3505   48.5268     76.78        78
# 6                    Rikitea -23.1203 -134.9692     77.63        73
# 7                  Tuatapere -46.1333  167.6833     52.77        94
# 8  Petropavlovsk-Kamchatskiy  53.0452  158.6483     12.79        41
# 9            Haines Junction  60.7522 -137.5108      6.39        99
#
#    Cloudiness  Wind Speed Country Current Description
# 0          75       16.11      BR       broken clouds
# 1           0        4.61      US           clear sky
# 2          94        5.37      PT          light snow
# 3          20       20.71      BR          few clouds
# 4          95        1.86      ID     overcast clouds
# 5          64       19.46      SO       broken clouds
# 6          69        5.50      PF       broken clouds
# 7          49        3.76      NZ    scattered clouds
# 8          75       24.61      RU       broken clouds
# 9         100        1.99      CA     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
# YOUR CODE HERE
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
# YOUR CODE HERE
city_data_df = city_data_df[new_column_order]

# Display sample data
# YOUR CODE HERE
city_data_df
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0              Natal      BR  -5.7950  -35.2094     83.05        78
# 1               Hilo      US  19.7297 -155.0900     81.28        79
# 2               Vila      PT  42.0304   -8.1588     34.68        90
# 3    Arraial Do Cabo      BR -22.9661  -42.0278     85.96        74
# 4               Palu      ID  -0.8917  119.8707     74.68        95
# ..               ...     ...      ...       ...       ...       ...
# 557           Mopipi      BW -21.1833   24.8833     80.47        49
# 558              Soe      ID  -9.8607  124.2840     66.16        94
# 559   Port Macquarie      AU -31.4333  152.9167     63.90        77
# 560           Kemise      ET  10.7167   39.8667     65.25        42
# 561           Nemuro      JP  43.3236  145.5750     20.32        72
#
#      Cloudiness  Wind Speed Current Description
# 0            75       16.11       broken clouds
# 1             0        4.61           clear sky
# 2            94        5.37          light snow
# 3            20       20.71          few clouds
# 4            95        1.86     overcast clouds
# ..          ...         ...                 ...
# 557          68        5.75       broken clouds
# 558         100        3.31     overcast clouds
# 559          46        8.25    scattered clouds
# 560           9        0.67           clear sky
# 561          53       16.42       broken clouds
#
# [562 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
# YOUR CODE HERE
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
# YOUR CODE HERE
output_data_file = "WeatherPy_Database.csv"
# Export the city_data DataFrame into a CSV file
# YOUR CODE HERE
city_data_df.to_csv(output_data_file, index_label="City_ID")
